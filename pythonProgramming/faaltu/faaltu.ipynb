# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import style

# %%
stockData = pd.read_csv("NIFTY50_all.csv")
stockData
# Out:
#               Date      Symbol Series  Prev Close    Open     High     Low  \
# 0       2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00
# 1       2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00
# 2       2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00
# 3       2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00
# 4       2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00
# ...            ...         ...    ...         ...     ...      ...     ...
# 232149  2020-11-23        ZEEL     EQ      185.50  187.00   188.00  183.75
# 232150  2020-11-24        ZEEL     EQ      187.20  189.00   190.90  187.50
# 232151  2020-11-25        ZEEL     EQ      188.30  189.85   193.50  187.00
# 232152  2020-11-26        ZEEL     EQ      188.40  190.00   190.95  187.10
# 232153  2020-11-27        ZEEL     EQ      189.75  190.80   201.00  190.05
#
#           Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
indexList= []
for i in range(0,20000):
    indexList.append(i)
plt.plot(indexList,stockData.head(20000)['Open'])
plt.show()
